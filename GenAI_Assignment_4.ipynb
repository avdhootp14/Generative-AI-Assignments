# %%
# !pip install transformers torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !pip install -q -U google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.0/141.0 kB 10.2 MB/s eta 0:00:00

# %%
from google import genai

client = genai.Client(api_key="AIzaSyCeRV3HFJH8h4sUZ2AgjI-uO8FR1fKxUjI")

def generate_answer_from_gemini(question: str):
    response = client.models.generate_content(
        model="gemini-2.0-flash", contents=question
    )
    return response.text

def chatbot():
    print("Chatbot: Hi! I'm using Gemini. Ask me anything!")
    while True:
        user_input = input("You: ")

        if user_input.lower() == "exit":
            print("Chatbot: Goodbye!")
            break

        answer = generate_answer_from_gemini(user_input)

        print(f"Chatbot: {answer}")

chatbot()
# Out:
# Chatbot: Hi! I'm using Gemini. Ask me anything!
# You: What is huggingface
# Chatbot: Hugging Face is a leading company and community in the field of Artificial Intelligence (AI), particularly known for its contributions to **Natural Language Processing (NLP)** and **Machine Learning (ML)**. It provides tools, libraries, and resources that make it easier for developers, researchers, and businesses to build, train, and deploy machine learning models.
#
# Here's a breakdown of what makes Hugging Face significant:
#
# *   **Transformers Library:** This is Hugging Face's flagship offering. It's an open-source library providing pre-trained models (like BERT, GPT, RoBERTa) and tools to fine-tune them for various NLP tasks, such as text classification, question answering, text generation, and more. The `transformers` library supports PyTorch, TensorFlow, and Flax. This library significantly lowers the barrier to entry for using state-of-the-art NLP models.
#
# ...
